# %% [markdown]
# <a href="https://colab.research.google.com/github/mmm404/TradingBot/blob/main/forex_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries
import tkinter as tk
from tkinter import *
from PIL import ImageTk, Image
from tkinter import ttk
import customtkinter as ctk  # Importing ctk from customtkinter module
import time

# layout
PATH = r'C:\Users\HP\Desktop\icon_logo.png'
image = Image.open(PATH)
root = ctk.CTk()  # Creating root window using ctk.CTk()
root.resizable(0, 0)
root.geometry('1100x600')
root.title('Trading Assistant')
icon = ImageTk.PhotoImage(image)
root.iconphoto(True, icon)

# commands
def buy_asset():

    #assetwindow
    asset_selection_win = tk.Tk()
    asset_selection_win.geometry('700x430')
    asset_selection_win.title('Select asset')
    asset_selection_win.config(background='#3dcef2')
    asset_selection_win.resizable(0,0)
    symbol = tk.Label(asset_selection_win, text='symbol',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    symbol_combobox = ttk.Combobox(asset_selection_win, values=('AUDUSD', 'EURUSD','XAUUSD','USDJPY','USDCAD'),width=13)
    symbol.place(x=80,y=40)
    symbol_combobox.place(x=145,y=30)

    #type
    type = tk.Label(asset_selection_win, text='type',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    type_combobox = ttk.Combobox(asset_selection_win, values=('INSTANT EXECUTION', 'PENDING ORDER'),width=13)
    type.place(x=430,y=40)
    type_combobox.place(x=475,y=30)

    # stop loss
    stop_loss_label = tk.Label(asset_selection_win, text='stop loss',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    stop_loss_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=1.0, to=1.5,width=15)
    stop_loss_label.place(x=65,y=100)
    stop_loss_spinbox.place(x=145,y=100)

    # take profit
    take_profit_label = tk.Label(asset_selection_win, text='take profit',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    take_profit_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=0.0, to=1.0,width=15)
    take_profit_label.place(x=400,y=100)
    take_profit_spinbox.place(x=475,y=100)

    #volume
    volume_label = tk.Label(asset_selection_win, text='volume',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    volume_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=0.00, to=1.0,width=13)
    volume_label.place(x=65,y=170)
    volume_spinbox.place(x=145,y=170)

    #deviation
    deviation = tk.Label(asset_selection_win, text='deviation',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    deviation_combobox = ttk.Combobox(asset_selection_win, values=('0','1','2','3','4','5','6','7','8'),width=13)
    deviation.place(x=400,y=170)
    deviation_combobox.place(x=475,y=170)

    #place order button
    place_order_btn = tk.Button(asset_selection_win,text='PLACE ORDER',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black',activebackground='#c0c0c0',activeforeground='black',height=1,width=13)
    place_order_btn.place(x=300,y=250)

    asset_selection_win.mainloop()


def sell_asset():

    asset_selection_win = tk.Tk()
    asset_selection_win.geometry('700x430')
    asset_selection_win.title('Select asset')
    asset_selection_win.config(background='#3dcef2')
    asset_selection_win.resizable(0,0)
    symbol = tk.Label(asset_selection_win, text='symbol',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    symbol_combobox = ttk.Combobox(asset_selection_win, values=('AUDUSD', 'EURUSD','XAUUSD','USDJPY','USDCAD'),width=13)
    symbol.place(x=80,y=40)
    symbol_combobox.place(x=145,y=30)

    #type
    type = tk.Label(asset_selection_win, text='type',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    type_combobox = ttk.Combobox(asset_selection_win, values=('INSTANT EXECUTION', 'PENDING ORDER'),width=13)
    type.place(x=430,y=40)
    type_combobox.place(x=475,y=30)

    # stop loss
    stop_loss_label = tk.Label(asset_selection_win, text='stop loss',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    stop_loss_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=1.0, to=1.5,width=15)
    stop_loss_label.place(x=65,y=100)
    stop_loss_spinbox.place(x=145,y=100)

    # take profit
    take_profit_label = tk.Label(asset_selection_win, text='take profit',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    take_profit_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=0.0, to=1.0,width=15)
    take_profit_label.place(x=400,y=100)
    take_profit_spinbox.place(x=475,y=100)

    #volume
    volume_label = tk.Label(asset_selection_win, text='volume',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    volume_spinbox = tk.Spinbox(asset_selection_win, format='%8.2f', increment=.01, from_=0.00, to=1.0,width=13)
    volume_label.place(x=65,y=170)
    volume_spinbox.place(x=145,y=170)

    #deviation
    deviation = tk.Label(asset_selection_win, text='deviation',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black')
    deviation_combobox = ttk.Combobox(asset_selection_win, values=('0','1','2','3','4','5','6','7','8'),width=13)
    deviation.place(x=400,y=170)
    deviation_combobox.place(x=475,y=170)

    #place order button
    place_order_btn = tk.Button(asset_selection_win,text='PLACE ORDER',font=('Times New Roman',11,'bold'),background='#c0c0c0',foreground='black',activebackground='#c0c0c0',activeforeground='black',height=1,width=13)
    place_order_btn.place(x=300,y=250)

    asset_selection_win.mainloop()


# scrollbar
scrollbar = ctk.CTkScrollbar(root)
scrollbar.pack(side=ctk.RIGHT, fill=ctk.Y)

# widgets
tg = tk.Text(root, bg='#5b96f5', yscrollcommand=scrollbar.set, height=28, width=120, padx=10, pady=10,font=('calibri',18,'bold italic'))
tg.place(x=150, y=20)
scrollbar.configure(command=tg.yview)

def refresh():
    def clear_label():
        green_light.configure(text='')

    tg.delete(1.0, tk.END)
    time.sleep(0.5)
    green_light = ctk.CTkLabel(root,text='Refreshed!')
    green_light.place(x=1000,y=20)
    tg.after(5000, clear_label)

# button
start_button = ctk.CTkButton(root,text='   START  ', cursor='plus', font=('calibri', 10, 'bold'),width = 20)
start_button.place(x=18, y=15)

refresh_button = ctk.CTkButton(root,text='  REFRESH ', cursor='plus', font=('calibri', 10, 'bold'),command=refresh,width = 20)
refresh_button.place(x=16, y=195)

indicators_button = ctk.CTkButton(root,text='INDICATORS', cursor='plus', font=('calibri', 10, 'bold'),width = 20)
indicators_button.place(x=12, y=150)

buy_button = ctk.CTkButton(root,text='    BUY   ', cursor='plus', command=buy_asset,width = 20, font=('calibri', 10, 'bold'))
buy_button.place(x=20, y=60)

sell_button = ctk.CTkButton(root,text='   SELL   ', cursor='plus', command=sell_asset,width = 20, font=('calibri', 10, 'bold'))
sell_button.place(x=20, y=105)

root.mainloop()
